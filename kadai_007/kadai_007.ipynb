# %%
pip install japanize-matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
df = pd.read_csv('sample_pandas_6.csv')

def tax(x):
    return x * 1.10

tax_series = df['単価'].apply(tax)
tax_series.name = '単価(税込み)'
pd.concat([df,tax_series],axis=1)

category_df = pd.read_csv('category.csv')

df = pd.merge(df,category_df[['商品番号','カテゴリー']],how='inner',on='商品番号')

category_counts = df['カテゴリー'].value_counts()

category_plot = category_counts.plot(kind='bar')

plt.xticks(rotation=0)
plt.title('カテゴリー別商品数', loc='left')
plt.xlabel("")

plt.show()

# %%
grouped = df.groupby('商品番号')['注文数'].agg(['sum', 'describe'])
grouped
# Out:
#            sum describe
#            注文数    count       mean        std  min   25%   50%   75%   max
# 商品番号
# 1QJFO8QY  1128     32.0  35.250000  18.461818  0.0  24.0  36.0  49.5  60.0
# 2HSTCDWM   588     20.0  29.400000  21.137146  0.0  12.0  27.0  48.0  60.0
# 48XMJXKO   216     10.0  21.600000  13.326665  0.0  13.5  21.0  30.0  42.0
# 8T7D5DQA   528     21.0  25.142857  18.260027  0.0  12.0  36.0  42.0  54.0
# MESUDVWQ   744     17.0  43.764706  18.219253  0.0  42.0  48.0  54.0  60.0
# QRMOGNUU   894     27.0  33.111111  16.588535  6.0  21.0  36.0  48.0  60.0
# S6RE8W6X   666     20.0  33.300000  21.631118  0.0  12.0  39.0  54.0  60.0
# X0ZE2ZMY   306     14.0  21.857143  21.901377  0.0   1.5  15.0  39.0  60.0
# YY4HAAZR   540     17.0  31.764706  18.095336  0.0  18.0  30.0  42.0  60.0
# Z4WOOIYV   588     22.0  26.727273  19.218498  0.0  12.0  24.0  42.0  60.0
